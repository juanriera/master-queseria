# %%
import os, sys
import os, sys
import pandas as pd
import datetime
import numpy as np
import matplotlib.pylab as pl
import matplotlib.pyplot as plt
import locale # para fechas y nombres de fechas en español
from scipy.stats import norm

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta a tu Mi Unidad en Google Drive
google_drive_path = '/content/drive/MyDrive/Colab Notebooks/'

try:
    os.chdir(google_drive_path)
    print(f"Directorio de trabajo cambiado a: {os.getcwd()}")
except FileNotFoundError:
    print(f"Error: La ruta '{google_drive_path}' no se encontró. Asegúrate de que Google Drive esté montado correctamente.")
except Exception as e:
    print(f"Ocurrió un error al cambiar el directorio: {e}")
# Out:
# Directorio de trabajo cambiado a: /content/drive/MyDrive/Colab Notebooks

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
os.path.exists("master-queseria/datos/datos_laboratorio.csv")
# Out:
# True

# %%
import chardet

with open("master-queseria/datos/datos_laboratorio.csv", "rb") as f:
    raw_data = f.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']

print(f"Codificación detectada: {encoding}")
# Out:
# Codificación detectada: ISO-8859-1

# %%
df_datos_laboratorio = pd.read_csv("master-queseria/datos/datos_laboratorio.csv", decimal = ",", sep=';', encoding=encoding)

# %%
df_datos_laboratorio.dtypes
# Out:
# fecha            object
# receta           object
# formato          object
# maduracion       object
# extractoseco    float64
# materiagrasa    float64
# sal             float64
# ph              float64
# dtype: object

# %%
df_datos_laboratorio.head()
# Out:
#         fecha    receta formato maduracion  extractoseco  materiagrasa   sal  \
# 0  07/10/2012  mezcla 5    3 kg     tierno     57.330002     32.139999  1.04
# 1  07/10/2012  mezcla 5   500 g     tierno     58.549999     32.980000  0.99
# 2  07/10/2012  mezcla 5    3 kg     tierno     58.509998     33.160000  1.16
# 3  07/10/2012  mezcla 5   500 g     tierno     59.009998     33.070000  1.27
# 4  07/10/2012  mezcla 5   500 g     tierno     57.869999     31.940001  0.93
#
#      ph
# 0  5.27
# 1  5.45
# 2  5.26
# 3  5.46
# 4  5.47

# %%
print(df_datos_laboratorio['receta'].value_counts())
# Out:
# receta
# mezcla 1            8421
# mezcla 7            6525
# mezcla 5            5307
# mezcla 8            2663
# mezcla 3 (oveja)    2332
# cabra                818
# mezcla 6 (oveja)      98
# Name: count, dtype: int64

# %%
df_datos_laboratorio.describe()
# Out:
#        extractoseco  materiagrasa           sal            ph
# count  24829.000000  24824.000000  24842.000000  26160.000000
# mean      57.969682     31.664560      1.249125      5.319088
# std        2.384453      3.782769      0.500360      0.989425
# min       42.430000     12.000000      0.000000      0.000000
# 25%       57.209999     31.030001      1.100000      5.270000
# 50%       58.360001     32.520000      1.300000      5.340000
# 75%       59.419998     33.900002      1.450000      5.400000
# max       69.300003     59.029999     31.500000     85.339996

# %%
df_datos_laboratorio['fecha_index']= pd.DatetimeIndex(df_datos_laboratorio.fecha).normalize()
df_datos_laboratorio.set_index('fecha_index',inplace=True)
df_datos_laboratorio.sort_index(inplace=True)
